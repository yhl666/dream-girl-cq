# %% [markdown]
# ### Matplotlib-图像处理

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 读取图片
# - imread

# %%
img = plt.imread('data/pandas.jpeg')
img
# Out:
# array([[[ 78,  20,  79],
#         [ 78,  20,  79],
#         [ 78,  20,  79],
#         ...,
#         [ 52,  55, 124],
#         [ 52,  55, 124],
#         [ 52,  55, 124]],
#
#        [[ 78,  20,  79],
#         [ 78,  20,  79],
#         [ 78,  20,  79],
#         ...,
#         [ 52,  55, 124],
#         [ 52,  55, 124],
#         [ 52,  55, 124]],
#
#        [[ 78,  20,  79],
#         [ 78,  20,  79],
#         [ 78,  20,  79],
#         ...,
#         [ 52,  55, 124],
#         [ 52,  55, 124],
#         [ 52,  55, 124]],
#
#        ...,
#
#        [[ 64,  26,  85],
#         [ 64,  26,  85],
#         [ 64,  26,  85],
#         ...,
#         [ 52,  71, 140],
#         [ 52,  71, 140],
#         [ 52,  71, 140]],
#
#        [[ 64,  26,  85],
#         [ 64,  26,  85],
#         [ 64,  26,  85],
#         ...,
#         [ 52,  71, 140],
#         [ 52,  71, 140],
#         [ 52,  71, 140]],
#
#        [[ 64,  26,  85],
#         [ 64,  26,  85],
#         [ 64,  26,  85],
#         ...,
#         [ 52,  71, 140],
#         [ 52,  71, 140],
#         [ 52,  71, 140]]], dtype=uint8)

# %% [markdown]
# ### 显示图片
# - imshow

# %%
plt.imshow(img)
plt.savefig('images/7-1.png')

# %%
# 垂直翻转显示
plt.imshow(img, origin='lower')

# 或
plt.imshow(img[::-1])

plt.savefig('images/7-2.png')

# %%
# 水平翻转
plt.imshow(img[:, ::-1])

plt.savefig('images/7-3.png')

# %% [markdown]
# ### 保存图片
# - imsave

# %%
# 保存左右翻转后的图片
plt.imsave('pandas.png', img[:, ::-1])
